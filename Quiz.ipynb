# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file = pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv")

# %%
file.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
file.tail()
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit  Y2014  Y2015  \
# 60938                                    Food      1000 tonnes  42.00  46.00
# 60939     Food supply quantity (kg/capita/yr)               kg   3.06   3.33
# 60940           Food supply (kcal/capita/day)  kcal/capita/day   3.00   4.00
# 60941  Protein supply quantity (g/capita/day)     g/capita/day   0.10   0.11
# 60942      Fat supply quantity (g/capita/day)     g/capita/day   0.04   0.05
#
#        Y2016  Y2017  Y2018
# 60938  33.00  19.00  16.00
# 60939   2.35   1.33   1.08
# ...

# %%
file.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
#file.isnull().sum()

# %%
file.loc[[0,1]]
# Out:
#    Area Code     Area  Item Code        Item  Element Code  \
# 0          4  Algeria       2501  Population           511
# 1          4  Algeria       2501  Population          5301
#
#                          Element          Unit    Y2014    Y2015    Y2016  \
# 0  Total Population - Both sexes  1000 persons  38924.0  39728.0  40551.0
# 1       Domestic supply quantity   1000 tonnes      0.0      0.0      0.0
#
#      Y2017    Y2018
# 0  41389.0  42228.0
# 1      0.0      0.0

# %%
#file.plot()

# %%
#file.duplicated().to_string()

# %%
#file.head()

# %%
#file['Y2014'].describe()

# %%
y2014_std = np.std(file['Y2014'])
print(np.mean(file['Y2014']))
print(np.mean(file['Y2015']))
print(np.mean(file['Y2016']))
print(np.mean(file['Y2017']))
print(np.mean(file['Y2018']))

# %%
print(y2014_std)
print(y2014_mean)
# Out:
# 1547.0784051734797
# 134.19628213767805

# %%
#file['Y2014'].fillna(y2014_mean, inplace=True)

# %%
#file['Y2014'].describe()

# %% [markdown]
# #define a function to fill the empty cells with the mean of that year
#
# def fill_empty(year):
#     file[year].fillna(np.mean(file[year]), inplace=True)
#
# #fill empty cells for Y2015 - 2018
# fill_empty('Y2015')
# fill_empty('Y2016')
# fill_empty('Y2017')
# fill_empty('Y2018')

# %%
file.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
plt.subplot(1,2,1)
plt.scatter(y=file['Y2014'], x=file['Y2014'])

plt.subplot(1,2,2)
plt.scatter(y=file['Y2015'], x=file['Y2015'])
plt.show()
plt.subplot(1,2,1)
plt.scatter(y=file['Y2016'], x=file['Y2016'])

plt.subplot(1,2,2)
plt.scatter(y=file['Y2017'], x=file['Y2016'])
plt.show()
plt.subplot(1,2,1)
plt.scatter(y=file['Y2018'], x=file['Y2018'])
plt.show()

# %%
file.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %%
file.groupby(['Y2014','Y2017']).sum()
# Out:
#                      Area Code  Item Code  Element Code     Y2015     Y2016  \
# Y2014     Y2017
# -1796.0    0.0             159       2657          5072     -73.0     -12.0
# -1631.0   -689.0           159       2924          5072       6.0     -77.0
# -849.0    -600.0           266       5444         10340   -1118.0   -1119.0
# -838.0    -538.0           184       2907          5072    -827.0    -679.0
# -685.0     689.0           143       2905          5072    3418.0   -3225.0
# ...                        ...        ...           ...       ...       ...
#  90425.0   96443.0          59       2501           511   92443.0   94447.0
#  98094.0   106400.0        238       2501           511  100835.0  103603.0
#  108756.0  112625.0        159       2907          5301  110798.0  116483.0
#  109593.0  117702.0        159       2907          5511  111663.0  119330.0
#  176405.0  190873.0        159       2501           511  181137.0  185960.0
#
#                         Y2018
# ...

# %%
print(np.mean(file['Y2015']))
print(np.std(file['Y2015']))
# Out:
# 135.23596649549236
# 1603.3904860828056

# %%
file['Y2015'].isnull().sum()
# Out:
# 1548

# %%
file.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %%
file.groupby(['Element Code']).sum()
# Out:
#               Area Code  Item Code       Y2014       Y2015       Y2016  \
# Element Code
# 511                6020     112545  1031585.00  1058081.00  1085107.00
# 645              658446   13185401    49650.63    49345.13    48985.28
# 664              674057   13511060   454257.00   453383.00   451810.00
# 674              675050   13535000    11836.46    11833.95    11779.69
# 684              675050   13535000    10225.56    10235.74    10102.77
# 5072             571566   11329527    58749.83    34910.99    33140.12
# 5123             274353    5424803   153223.00   155439.00   157787.00
# 5131             271940    5350416   282923.00   287929.00   280631.00
# 5142             663295   13285035  1212332.49  1232361.10  1247022.17
# 5154             235554    4729749    78718.13    66254.41    69563.68
# 5170             623271   12421089    30149.00    30045.00    37224.00
# 5171              50308    1486528      416.00      349.00       89.00
# ...

# %%
file.groupby(['Element Code','Y2014']).sum()
# Out:
#                       Area Code  Item Code    Y2015    Y2016    Y2017    Y2018
# Element Code Y2014
# 511          196.0          193       2501    199.0    203.0    207.0    211.0
#              518.0           35       2501    525.0    531.0    537.0    544.0
#              899.0           72       2501    914.0    929.0    944.0    959.0
#              1095.0         209       2501   1104.0   1114.0   1125.0   1136.0
#              1257.0         137       2501   1259.0   1262.0   1264.0   1267.0
# ...                         ...        ...      ...      ...      ...      ...
# 5911         3384.0         202       2905   1873.0   2006.0   3095.0   3117.0
#              3669.0         202       2919   3719.0   3835.0   4120.0   4460.0
#              4144.0         202       2946   6655.0   6419.0   7223.0   7220.0
#              19818.0        136       2946  14200.0  20302.0  34641.0  34641.0
#              39686.0        143       2946  52578.0  35420.0  34515.0  34511.0
#
# ...

# %%
file[['Y2018','Element']].groupby(['Element']).sum()
# Out:
#                                              Y2018
# Element
# Domestic supply quantity                2161192.10
# Export Quantity                          181594.80
# Fat supply quantity (g/capita/day)        10258.69
# Feed                                     233489.68
# Food                                    1303841.28
# Food supply (kcal/capita/day)            455261.00
# Food supply quantity (kg/capita/yr)       49056.85
# Import Quantity                          287997.09
# Losses                                   163902.00
# Other uses (non-food)                     91300.97
# Processing                               308429.00
# Production                              2075072.89
# Protein supply quantity (g/capita/day)    11833.56
# Residuals                                 34864.00
# Seed                                      25263.14
# Stock Variation                           20577.91
# Total Population - Both sexes           1140605.00
# ...

# %%
file.groupby(['Element']).count()
# Out:
#                                         Area Code  Area  Item Code  Item  \
# Element
# Domestic supply quantity                     5295  5295       5295  5295
# Export Quantity                              4403  4403       4403  4403
# Fat supply quantity (g/capita/day)           5023  5023       5023  5023
# Feed                                         1319  1319       1319  1319
# Food                                         4941  4941       4941  4941
# Food supply (kcal/capita/day)                5014  5014       5014  5014
# Food supply quantity (kg/capita/yr)          4905  4905       4905  4905
# Import Quantity                              5139  5139       5139  5139
# Losses                                       2009  2009       2009  2009
# Other uses (non-food)                        1732  1732       1732  1732
# Processing                                   2010  2010       2010  2010
# Production                                   3881  3881       3881  3881
# ...

# %%
file.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
file.dropna(inplace=True)

# %%
#12

# %%
#13
file['Y2016'].describe()
# Out:
# count     57784.000000
# mean        140.376380
# std        1662.732983
# min       -3225.000000
# 25%           0.000000
# 50%           0.130000
# 75%           9.000000
# max      185960.000000
# Name: Y2016, dtype: float64

# %%
#14
file.corr()
#Ans 2014

# %%
#15
file.groupby('Element').sum()
#Ans Y2017
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   698435   13986139      27634113
# Export Quantity                            415968    7894703      17224654
# Fat supply quantity (g/capita/day)         662095   13289323       3370752
# Feed                                       144633    2933176       6012369
# Food                                       652391   13091136      25020972
# Food supply (kcal/capita/day)              659187   13227714       3256920
# Food supply quantity (kg/capita/yr)        647542   12991502       3115350
# Import Quantity                            621285   12533807      26102372
# Losses                                     274321    5422290      10286984
# Other uses (non-food)                      208464    4179786       7859850
# Processing                                 268111    5266227      10149118
# ...

# %%
#16
file.groupby('Element').sum()
#Ans 1931264.75
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   698435   13986139      27634113
# Export Quantity                            415968    7894703      17224654
# Fat supply quantity (g/capita/day)         662095   13289323       3370752
# Feed                                       144633    2933176       6012369
# Food                                       652391   13091136      25020972
# Food supply (kcal/capita/day)              659187   13227714       3256920
# Food supply quantity (kg/capita/yr)        647542   12991502       3115350
# Import Quantity                            621285   12533807      26102372
# Losses                                     274321    5422290      10286984
# Other uses (non-food)                      208464    4179786       7859850
# Processing                                 268111    5266227      10149118
# ...

# %%
#17
group = file[['Y2018','Element']].groupby('Element').sum().reset_index()
group.sort_values('Y2018', ascending=False)
#Ans Domestic supply quantity

# %%
# 18

group = file[['Y2018','Element']].groupby('Element').sum().reset_index()
group.sort_values('Y2018', ascending=False)

#Ans Seed
# Out:
#                                    Element       Y2018
# 0                 Domestic supply quantity  2161167.10
# 11                              Production  2075025.89
# 4                                     Food  1303806.28
# 16           Total Population - Both sexes  1140605.00
# 5            Food supply (kcal/capita/day)   455241.00
# 10                              Processing   308421.00
# 7                          Import Quantity   287736.09
# 3                                     Feed   233441.68
# 1                          Export Quantity   181067.80
# 8                                   Losses   163902.00
# 9                    Other uses (non-food)    91273.97
# 6      Food supply quantity (kg/capita/yr)    49055.02
# 13                               Residuals    34864.00
# 14                                    Seed    25263.14
# 15                         Stock Variation    20579.91
# 12  Protein supply quantity (g/capita/day)    11833.43
# ...

# %%
#19

file.groupby(['Area','Element']).sum().head(17)
Ans: 36238.29
# Out:
#                                                 Area Code  Item Code  \
# Area    Element
# Algeria Domestic supply quantity                      452     303390
#         Export Quantity                               220     149926
#         Fat supply quantity (g/capita/day)            428     288746
#         Feed                                           80      53444
#         Food                                          416     280001
#         Food supply (kcal/capita/day)                 428     288746
#         Food supply quantity (kg/capita/yr)           416     280001
#         Import Quantity                               408     274912
#         Losses                                        208     139857
#         Other uses (non-food)                         140      95593
#         Processing                                    140      93537
#         Production                                    356     240054
# ...

# %%
#20 
file.groupby('Area').describe()
Ans: 49
# Out:
#                             Area Code                                          \
#                                 count   mean  std    min    25%    50%    75%
# Area
# Algeria                        1244.0    4.0  0.0    4.0    4.0    4.0    4.0
# Angola                         1350.0    7.0  0.0    7.0    7.0    7.0    7.0
# Benin                          1212.0   53.0  0.0   53.0   53.0   53.0   53.0
# Botswana                       1342.0   20.0  0.0   20.0   20.0   20.0   20.0
# Burkina Faso                   1343.0  233.0  0.0  233.0  233.0  233.0  233.0
# Cabo Verde                     1161.0   35.0  0.0   35.0   35.0   35.0   35.0
# Cameroon                       1415.0   32.0  0.0   32.0   32.0   32.0   32.0
# Central African Republic       1242.0   37.0  0.0   37.0   37.0   37.0   37.0
# Chad                           1232.0   39.0  0.0   39.0   39.0   39.0   39.0
# Comoros                          45.0   45.0  0.0   45.0   45.0   45.0   45.0
# ...
